# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import librosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b4d2b2c01611> in <module>()
#       2 import torch
#       3 import matplotlib.pyplot as plt
# ----> 4 import librosa
#
# ModuleNotFoundError: No module named 'librosa'

# %%
# def visualize_result(path):
#     mean_ECG = -55.18958194
#     std_ECG = 20.79336364    
#     mean_PPG = -72.7312628
#     std_PPG = 18.75779879
#     def unnormalize_signal(Signal, mean, std):
#         Signal = (Signal * std) + mean
#         return Signal
#     result = torch.load(path)
#     # step 000
#     ECG1_000 = result[0][0][0,0,:]   # torch.size([63, 37])
#     ECG2_000 = result[0][0][0,1,:]
#     PPG_000 = result[0][0][0,2,:]
#     print(f"step 000, label: {result[0][1]}")
#     # step 029
#     ECG1_029 = result[29][0][0,0,:]
#     ECG2_029 = result[29][0][0,1,:]
#     PPG_029 = result[29][0][0,2,:]
#     print(f"step 029, label: {result[29][1]}")

# path = "/PublicSSD/jhpark/dataset-distillation/results/distill_reg/PULSEDB/arch(LeNetReg,xavier,1.0)_distillLR2e-06_E(444,40,0.5)_lr0.0001_B1x10x3_train(unknown_init)/checkpoints/epoch0160/results.pth"
# visualize_result(path)
# Out:
# step 000, label: tensor([143.0456,  86.8632, 143.6505, 101.6713, 116.9531,  82.4358, 107.4923,
#         174.8944, 106.6644, 114.9099, 114.9338, 109.2126, 146.7569,  86.5294,
#         135.4980,  99.1350, 109.5195, 141.7505,  96.5550,  96.1507, 108.9156,
#         160.7858, 107.0699, 120.3830,  97.2699, 124.5337,  78.9468, 120.8225,
#          97.2020, 110.7521,  94.1825, 123.0901,  96.2780, 100.0753, 138.7135,
#         127.1600, 109.4976, 125.8505,  99.7519, 113.5001, 110.3171, 134.5207,
#         116.1283,  88.5445, 120.1592,  83.4132,  92.9899, 122.3722, 153.5261,
#         134.5441,  88.5334, 100.8276,  96.7935, 111.0327,  95.9135,  97.4209,
#         129.0019, 130.6257, 123.8388,  98.8378,  94.9287, 111.0476, 131.2672,
#         106.5256, 164.5732, 124.5052, 137.4688, 106.3168,  97.5811, 162.8707,
#          84.4511, 114.1519,  97.3374, 105.6080, 142.0725,  90.5030, 103.9120,
#         134.7561,  96.3280, 119.3531])
# ...

# %%
def show_spectrograms(Signal, index):
    '''
    Draw the spectrograms of ECG and PPG
    Input: Signal: (N, 2, 63, 37)   stft of ECG and PPG with n_fft=125, hop_length=125//4, win_length=125
    '''
    plt.figure(figsize=(8, 5))
    librosa.display.specshow(Signal[index,0,:], sr=125, n_fft=125, hop_length=125//4, x_axis="time", y_axis="log", cmap="viridis")
    plt.title("Spectrogram - ECG")
    plt.xlabel("Time [s]")
    plt.ylabel("Frequency [Hz]")
    plt.colorbar().set_label("Intensity [dB]")
    plt.show()
    plt.figure(figsize=(8, 5))
    librosa.display.specshow(Signal[index,1,:], sr=125, n_fft=125, hop_length=125//4, x_axis="time", y_axis="log", cmap="viridis")
    plt.title("Spectrogram - PPG")
    plt.xlabel("Time [s]")
    plt.ylabel("Frequency [Hz]")
    plt.colorbar().set_label("Intensity [dB]")
    plt.show()

# %%
result[0][0].shape
# Out:
# torch.Size([80, 3, 63, 37])

# %%
# Test loading
def loading_result(path):
    device = torch.device('cpu')
    
                
# randinit & sixman
path = "/PublicSSD/jhpark/dataset-distillation/results/distill_reg/PULSEDB/arch(LeNetReg,xavier,1.0)_distillLR3e-05_E(500,40,0.5)_lr0.0001_B1x10x3_train(unknown_init)/results.pth"
result = torch.load(path)  # list of 30 tuple. each tuple == (torch.Tensor(1, 3, 63, 37), tensor([110., 115., 117., 118., 119., 120., 121., 123., 125., 130.]), tensor([3.0078e-05]))

# loadinit & sixman
# path = "/PublicSSD/jhpark/dataset-distillation/results/distill_reg/PULSEDB/arch(LeNetReg,xavier,1.0)_distillLR2e-06_E(444,40,0.5)_lr0.0001_B1x10x3_train(unknown_init)/checkpoints/epoch0150/results.pth"
path = "/PublicSSD/jhpark/dataset-distillation/results/distill_reg/PULSEDB/arch(LeNetReg,xavier,1.0)_distillLR2e-06_E(444,40,0.5)_lr0.0001_B1x10x3_train(unknown_init)/checkpoints/epoch0160/results.pth"
result = torch.load(path)

# %%
result[-1]
# Out:
# (tensor([[[[ 2.7141,  2.7003,  2.7503,  ...,  2.7036,  2.6556,  2.6601],
#            [ 2.4319,  2.3435,  2.5318,  ...,  2.4480,  2.2719,  2.4546],
#            [ 1.3132,  1.9033,  1.7738,  ...,  0.5339,  1.9169,  1.7496],
#            ...,
#            [-1.3328, -1.3026, -1.3312,  ..., -1.2356, -1.2672, -1.1939],
#            [-1.2441, -1.2095, -1.2182,  ..., -1.2028, -1.2256, -1.2238],
#            [-1.1728, -1.1899, -1.1812,  ..., -1.1906, -1.1957, -1.1920]],
#
#           [[ 2.7259,  2.6973,  2.7541,  ...,  2.7049,  2.6529,  2.6614],
#            [ 2.4418,  2.3389,  2.5292,  ...,  2.4484,  2.2638,  2.4532],
#            [ 1.3145,  1.8985,  1.7778,  ...,  0.5232,  1.9259,  1.7624],
#            ...,
#            [-1.2807, -1.2545, -1.3113,  ..., -1.2794, -1.2849, -1.2285],
#            [-1.2446, -1.2387, -1.2283,  ..., -1.2359, -1.2378, -1.2028],
#            [-1.1987, -1.1999, -1.1961,  ..., -1.1881, -1.1956, -1.1928]],
#
# ...

# %%
result[0][0].shape
# Out:
# torch.Size([80, 3, 63, 37])

# %%
# show mnist result
mnistpath = "/PublicSSD/jhpark/dataset-distillation/results/distill_basic/MNIST/arch(LeNet,xavier,1.0)_distillLR0.02_E(400,40,0.5)_lr0.01_B1x10x3_train(unknown_init)/results.pth"
mnistresult = torch.load(mnistpath)

# %%
mnistresult[0][0].shape
# Out:
# torch.Size([10, 1, 28, 28])

# %%
def load_results(state, save_data_path=None, device=None):
    if save_data_path is None:
        expr_dir = state.get_load_directory()
        save_data_path = os.path.join(expr_dir, 'results.pth')
    device = device or state.device
    return to_torch(torch.load(save_data_path, map_location=device), device)

            if state.test_distilled_images == 'loaded':
                unique_data_label = [s[:-1] for s in loaded_steps[:state.distill_steps]]

                def get_data_label(state):
                    return [x for _ in range(state.distill_epochs) for x in unique_data_label]

# %%
# Build a CNN model for distillation

import torch
from torch import nn
import torch.nn.functional as F

class RegressionCNN(nn.Module):
    def __init__(self):
        super(RegressionCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(4320, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Create model instance
model = RegressionCNN()

# Example usage:
input_tensor = torch.randn(100, 3, 63, 37)
output = model(input_tensor)
print(output.shape)  # Output should be torch.Size([batch_size, 1])
# Out:
# torch.Size([100, 1])
